# %%
import networkx as nx
import json
import matplotlib.pyplot as plt

# %%
GRAPH_PATH = '/Users/zoeshleifer/promys2020/lab/small_final_graph.txt'
DISTANCE_PATH = '/Users/zoeshleifer/promys2020/lab/Gerrymandering2-promys2020/distance_data.txt'
DISTRICT_PATH = '/Users/zoeshleifer/promys2020/lab/original_districts.txt'

# %%
with open(GRAPH_PATH, "r") as read_file:
    data = json.load(read_file)
G = nx.json_graph.node_link_graph(data)
with open(DISTANCE_PATH, "r") as read_file:
    dist_dict = json.load(read_file)
with open(DISTRICT_PATH, "r") as read_file:
    sch_dict = json.load(read_file)

# %%
dist_dict['420454069042']['420912058011'] 
#dist_dict[block ID][block with school ID]
#all values are in seconds, this should be 2057
# Out:
# 2057

# %%
with open(GRAPH_PATH, "r") as read_file:
    G_dict = json.load(read_file)

# %%
G_dict['nodes']
# Out:
# [{'population': 56.0,
#   'minority': 35.0,
#   'hasschool': True,
#   'position': [39.947773, -75.2728757],
#   'id': '420454018001'},
#  {'population': 20.0,
#   'minority': 2.0,
#   'hasschool': False,
#   'position': [39.942126, -75.2767574],
#   'id': '420454019002'},
#  {'population': 42.0,
#   'minority': 41.0,
#   'hasschool': False,
#   'position': [39.930425, -75.2553121],
#   'id': '420454021003'},
#  {'population': 47.0,
#   'minority': 27.0,
#   'hasschool': False,
#   'position': [39.941457, -75.2695901],
#   'id': '420454018003'},
#  {'population': 24.0,
#   'minority': 14.0,
#   'hasschool': False,
#   'position': [39.937535, -75.269792],
#   'id': '420454020001'},
#  {'population': 35.0,
#   'minority': 9.0,
#   'hasschool': False,
#   'position': [39.922416, -75.2816437],
#   'id': '420454032002'},
#  {'population': 55.0,
#   'minority': 55.0,
#   'hasschool': False,
#   'position': [39.920179, -75.2611345],
#   'id': '420454025001'},
#  {'population': 27.0,
# ...

# %%
fig = plt.figure(figsize = [20,15])
ax = fig.add_subplot(1, 1, 1)
nodes=G.nodes()
edges = G.edges()
colorz = [[u]['color'] for u in nodes]
positions = [tuple(G.nodes[u]['position']) for u in nodes]
nx.draw(small_G,orientation=u'vertical',ax=ax,nodes=nodes, pos=attrs['POS'],node_color=attrs['assig'].cat.codes, cmap=mymap, edges=edges,node_size=sizes, with_labels=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-a2087e5cdc6e> in <module>
#       3 nodes=G.nodes()
#       4 edges = G.edges()
# ----> 5 colorz = [G.nodes[u]['color'] for u in nodes]
#       6 positions = [tuple(G.nodes[u]['position']) for u in nodes]
#       7 nx.draw(G,ax=ax,nodes=nodes,node_color=colorz,pos=nx.get_node_attributes(G,'position'),edges=edges, with_labels=False)
#
# <ipython-input-14-a2087e5cdc6e> in <listcomp>(.0)
#       3 nodes=G.nodes()
#       4 edges = G.edges()
# ----> 5 colorz = [G.nodes[u]['color'] for u in nodes]
#       6 positions = [tuple(G.nodes[u]['position']) for u in nodes]
#       7 nx.draw(G,ax=ax,nodes=nodes,node_color=colorz,pos=nx.get_node_attributes(G,'position'),edges=edges, with_labels=False)
#
# KeyError: 'color'

# %%
True >False
# Out:
# True
